# %% [markdown]
# <a href="https://colab.research.google.com/github/vdr-maker/Binus-Python/blob/main/Pertemuan7/DataScience2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Membuat data dummy menggunakan dictionary
data_negara = {
    "Negara": [
        "Indonesia",
        "Malaysia",
        "Singapura",
        "Thailand",
        "Vietnam",
        "Filipina",
        "Jepang",
        "Korea Selatan",
        "China",
        "India"
    ],
    "Populasi_Juta": [
        277.5,
        34.3,
        5.9,
        71.8,
        100.3,
        114.2,
        123.3,
        51.7,
        1410.7,
        1428.6
    ]
}

# Mengkonversi dictionary menjadi DataFrame
df = pd.DataFrame(data_negara)

# Menulis DataFrame ke file CSV
df.to_csv("data_negara.csv", index=False)

# Menampilkan DataFrame
print("===== Data Negara =====")
print(df)

print("\nFile CSV berhasil dibuat: data_negara.csv")
# Out:
# ===== Data Negara =====
#           Negara  Populasi_Juta
# 0      Indonesia          277.5
# 1       Malaysia           34.3
# 2      Singapura            5.9
# 3       Thailand           71.8
# 4        Vietnam          100.3
# 5       Filipina          114.2
# 6         Jepang          123.3
# 7  Korea Selatan           51.7
# 8          China         1410.7
# 9          India         1428.6
#
# File CSV berhasil dibuat: data_negara.csv
